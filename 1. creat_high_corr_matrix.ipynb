# %% [markdown]
# # 1. Import Libraries and Load Data

# %%
import numpy as np
import pandas as pd

# Load the correlation matrix
# We assume the first column contains the metabolite names
df = pd.read_csv("data/cleaned_correlation_matrix.csv", index_col=0)

# Display the first few rows to confirm loading
print(f"Matrix Shape: {df.shape}")
df.head()
# Out:
# Matrix Shape: (76, 76)
#                       creatinine  ethanol  trimethylaminenoxide  alanine  \
# creatinine               1.00000  0.07814               0.03168  0.14584
# ethanol                  0.07814  1.00000               0.06636  0.08009
# trimethylaminenoxide     0.03168  0.06636               1.00000  0.01601
# alanine                  0.14584  0.08009               0.01601  1.00000
# creatine                -0.37902  0.03469               0.05544  0.06048
#
#                       creatine  glutamic acid  glutamine  glycine  histidine  \
# creatinine            -0.37902        0.07273    0.21373  0.04715   -0.10091
# ethanol                0.03469        0.19316   -0.21366  0.01039    0.08311
# trimethylaminenoxide   0.05544        0.02380   -0.01576  0.00279    0.00994
# alanine                0.06048        0.17056    0.17464  0.26960    0.26182
# creatine               1.00000        0.00776   -0.15962  0.12851    0.15773
#
#                       isoleucine  ...  Inosine  Butyrylcarnitine  \
# creatinine               0.16251  ...  0.01048           0.17717
# ethanol                  0.17847  ... -0.10151          -0.07398
# trimethylaminenoxide     0.07539  ... -0.09184           0.08325
# alanine                  0.41513  ... -0.00564           0.00111
# creatine                 0.10401  ...  0.00079           0.02455
#
#                       7-Methylguanine  N1-methyl-2-pyridone-5-carboxamide  \
# creatinine                    0.16461                             0.13251
# ethanol                       0.07330                            -0.04453
# trimethylaminenoxide          0.01668                            -0.00740
# alanine                       0.09840                             0.01961
# creatine                     -0.10936                             0.20354
#
#                       N1-methyl-4-pyridone-3-carboxamide  Cortisol  \
# creatinine                                       0.14086  -0.06632
# ethanol                                         -0.01756  -0.22178
# trimethylaminenoxide                            -0.02001  -0.07739
# alanine                                          0.04237  -0.05606
# creatine                                         0.17871   0.03309
#
#                       N4-Acetylcytidine  1-Methyl-2-piperidinecarboxylate  \
# creatinine                      0.10905                           0.10998
# ethanol                        -0.12426                          -0.06994
# trimethylaminenoxide            0.00742                          -0.00403
# alanine                         0.00366                          -0.03541
# creatine                       -0.00460                          -0.00684
#
#                       Tetradecanoylcarnitine  Tetradecadienoylcarnitine
# creatinine                          -0.00485                   -0.00593
# ethanol                              0.01798                    0.00486
# trimethylaminenoxide                -0.02292                   -0.07747
# alanine                             -0.17870                   -0.29331
# creatine                            -0.02481                   -0.13354
#
# [5 rows x 76 columns]

# %% [markdown]
# # 2. Extract Non-Redundant Correlation Pairs

# %%
# Create a mask for the lower triangle of the matrix (excluding the diagonal)
mask = np.tril(np.ones(df.shape), k=-1).astype(bool)

# Apply the mask and "stack" the data into a long format
df_pairs = df.where(mask).stack().reset_index()

# Rename columns for clarity
df_pairs.columns = ["Metabolite_1", "Metabolite_2", "Correlation"]

print("Pairs extracted successfully.")
# Out:
# Pairs extracted successfully.

# %%
df_pairs
# Out:
#                    Metabolite_1                        Metabolite_2  \
# 0                       Ethanol                          Creatinine
# 1          Trimethylaminenoxide                          Creatinine
# 2          Trimethylaminenoxide                             Ethanol
# 3                       Alanine                          Creatinine
# 4                       Alanine                             Ethanol
# ...                         ...                                 ...
# 2845  Tetradecadienoylcarnitine  N1-methyl-4-pyridone-3-carboxamide
# 2846  Tetradecadienoylcarnitine                            Cortisol
# 2847  Tetradecadienoylcarnitine                   N4-Acetylcytidine
# 2848  Tetradecadienoylcarnitine    1-Methyl-2-piperidinecarboxylate
# 2849  Tetradecadienoylcarnitine              Tetradecanoylcarnitine
#
#       Correlation
# 0         0.07814
# 1         0.03168
# 2         0.06636
# 3         0.14584
# 4         0.08009
# ...           ...
# 2845      0.08971
# 2846      0.13880
# 2847      0.16579
# 2848      0.02331
# 2849      0.65467
#
# [2850 rows x 3 columns]

# %% [markdown]
# # 3. Filter for High Correlations (0.7 to 1.0)

# %%
# Define the threshold
threshold = 0.7

# Filter for both positive and negative correlations
high_corr = df_pairs[
    (df_pairs["Correlation"].abs() >= threshold) & (df_pairs["Correlation"].abs() < 1.0)
].copy()

# Add a column for absolute value to help with sorting
high_corr["Abs_Correlation"] = high_corr["Correlation"]

# Sort by strongest correlation
high_corr = high_corr.sort_values(by="Abs_Correlation", ascending=False).drop(
    columns="Abs_Correlation"
)

# Reset index for the final table
high_corr = high_corr.reset_index(drop=True)

print(f"Found {len(high_corr)} highly correlated pairs.")
# Out:
# Found 19 highly correlated pairs.

# %% [markdown]
# # 4. Display Results

# %%
# Display the count
print(f"Total number of highly correlated metabolites (|r| >= 0.7): {len(high_corr)}")

# Show the top pairs
high_corr
# Out:
# Total number of highly correlated metabolites (|r| >= 0.7): 19
#                           Metabolite_1                        Metabolite_2  \
# 0                              Inosine                        Hypoxanthine
# 1                    1-methylhistidine                   3-methylhistidine
# 2   N1-methyl-4-pyridone-3-carboxamide  N1-methyl-2-pyridone-5-carboxamide
# 3            Tetradecadienoylcarnitine            Hydroxydecanoylcarnitine
# 4             Hydroxydecanoylcarnitine                   Octanoylcarnitine
# 5                     N-methyl proline                     Proline betaine
# 6                    Octanoylcarnitine                   Hexanoylcarnitine
# 7            Tetradecadienoylcarnitine                   Octanoylcarnitine
# 8                Hexadecenoylcarnitine                     Oleoylcarnitine
# 9               Tetradecanoylcarnitine               Hexadecenoylcarnitine
# 10                     Oleoylcarnitine                   Stearoylcarnitine
# 11               Hexadecenoylcarnitine                  Palmitoylcarnitine
# 12                            Caffeine                        Paraxanthine
# 13           Tetradecadienoylcarnitine                   Hexanoylcarnitine
# 14            Hydroxydecanoylcarnitine                   Hexanoylcarnitine
# 15                     Oleoylcarnitine                  Palmitoylcarnitine
# 16                   Stearoylcarnitine                  Palmitoylcarnitine
# 17              Tetradecanoylcarnitine                  Palmitoylcarnitine
# 18                  Linoleoylcarnitine                     Oleoylcarnitine
#
#     Correlation
# 0       0.99999
# 1       0.99789
# 2       0.93884
# 3       0.85685
# 4       0.84801
# 5       0.83810
# 6       0.82867
# 7       0.82407
# 8       0.79527
# 9       0.79198
# 10      0.76678
# 11      0.76541
# 12      0.75058
# 13      0.74511
# 14      0.74311
# 15      0.74273
# 16      0.73739
# 17      0.70766
# 18      0.70041

# %% [markdown]
# # Creating a highly correlated adjacency matrix

# %% [markdown]
# # 1. Identify Unique High-Correlation Metabolites

# %%
import numpy as np
import pandas as pd

# Load the original correlation matrix
df = pd.read_csv("data/cleaned_correlation_matrix.csv", index_col=0)

# Identify pairs with |r| >= 0.7 (excluding self-correlation of 1.0)
mask = np.tril(np.ones(df.shape), k=-1).astype(bool)
pairs = df.where(mask).stack().reset_index()
pairs.columns = ["Met1", "Met2", "Corr"]

# Filter for the 19 highly correlated pairs
high_corr_pairs = pairs[(pairs["Corr"].abs() >= 0.7) & (pairs["Corr"].abs() < 1.0)]

# Get the list of unique metabolites involved
unique_mets = sorted(
    list(set(high_corr_pairs["Met1"]).union(set(high_corr_pairs["Met2"])))
)

print(f"Number of unique metabolites: {len(unique_mets)}")
# Out:
# Number of unique metabolites: 20

# %% [markdown]
# # 2. Create the Weighted Adjacency Matrix

# %%
# Extract the sub-matrix for these unique metabolites
adj_matrix = df.loc[unique_mets, unique_mets].copy()

# Define the Weighted Adjacency logic:
# Keep the correlation value if |r| >= 0.7, otherwise set to 0.
# We also set the diagonal to 0 because a node doesn't have an 'edge' to itself in this context.
weighted_adj = adj_matrix.map(lambda x: x if 0.7 <= abs(x) < 1.0 else 0)

# Display the dimensions
print(f"Weighted Adjacency Matrix Shape: {weighted_adj.shape}")
# Out:
# Weighted Adjacency Matrix Shape: (20, 20)

# %% [markdown]
# # 3. Save and Inspect the Result

# %%
# Save the adjacency matrix
weighted_adj.to_csv("data/weighted_high_corr_adjacency_matrix.csv")

weighted_adj
# Out:
#                                     1-methylhistidine  3-methylhistidine  \
# 1-methylhistidine                             0.00000            0.99789
# 3-methylhistidine                             0.99789            0.00000
# Caffeine                                      0.00000            0.00000
# Hexadecenoylcarnitine                         0.00000            0.00000
# Hexanoylcarnitine                             0.00000            0.00000
# Hydroxydecanoylcarnitine                      0.00000            0.00000
# Hypoxanthine                                  0.00000            0.00000
# Inosine                                       0.00000            0.00000
# Linoleoylcarnitine                            0.00000            0.00000
# N-methyl proline                              0.00000            0.00000
# N1-methyl-2-pyridone-5-carboxamide            0.00000            0.00000
# N1-methyl-4-pyridone-3-carboxamide            0.00000            0.00000
# Octanoylcarnitine                             0.00000            0.00000
# Oleoylcarnitine                               0.00000            0.00000
# Palmitoylcarnitine                            0.00000            0.00000
# Paraxanthine                                  0.00000            0.00000
# Proline betaine                               0.00000            0.00000
# Stearoylcarnitine                             0.00000            0.00000
# Tetradecadienoylcarnitine                     0.00000            0.00000
# Tetradecanoylcarnitine                        0.00000            0.00000
#
#                                     Caffeine  Hexadecenoylcarnitine  \
# 1-methylhistidine                    0.00000                0.00000
# 3-methylhistidine                    0.00000                0.00000
# Caffeine                             0.00000                0.00000
# Hexadecenoylcarnitine                0.00000                0.00000
# Hexanoylcarnitine                    0.00000                0.00000
# Hydroxydecanoylcarnitine             0.00000                0.00000
# Hypoxanthine                         0.00000                0.00000
# Inosine                              0.00000                0.00000
# Linoleoylcarnitine                   0.00000                0.00000
# N-methyl proline                     0.00000                0.00000
# N1-methyl-2-pyridone-5-carboxamide   0.00000                0.00000
# N1-methyl-4-pyridone-3-carboxamide   0.00000                0.00000
# Octanoylcarnitine                    0.00000                0.00000
# Oleoylcarnitine                      0.00000                0.79527
# Palmitoylcarnitine                   0.00000                0.76541
# Paraxanthine                         0.75058                0.00000
# Proline betaine                      0.00000                0.00000
# Stearoylcarnitine                    0.00000                0.00000
# Tetradecadienoylcarnitine            0.00000                0.00000
# Tetradecanoylcarnitine               0.00000                0.79198
#
#                                     Hexanoylcarnitine  \
# 1-methylhistidine                             0.00000
